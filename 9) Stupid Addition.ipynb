# %%
def Stupid_addition(var1,var2):
  if type(var1)==type(var2):
    if type(var1)==int:
      return str(var1)+str(var2)
    else:
      return int(var1)+int(var2)
  else:
    return "None"

# %%
Stupid_addition("2",1)
# Out:
# 'None'
