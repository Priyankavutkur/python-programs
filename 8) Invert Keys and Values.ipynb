# %%
def Invert_key_and_values(dicti):
  dicti_temp=dict()
  for key, value in dicti.items():
    dicti_temp[value]=key
  return dicti_temp

# %%
Invert_key_and_values({"a":"b","c":"d"})
# Out:
# {'b': 'a', 'd': 'c'}
