# %%
def invert_list(num_list):
  inverted_list=[]
  for i in num_list:
      inverted_list.append(i*-1)
  return inverted_list

# %%
num_list=input().split(" ")
invert_list(list(map(int, num_list)))
# Out:
# 1 2 3 -10 5
# [-1, -2, -3, 10, -5]
