# %%
def replacing(word):
    letter_2=""
    for char in word:
        num_1=chr(ord(char)+1)
        letter_2=letter_2+num_1
        if num_1=="!":
            letter_2=letter_2.replace("!","")
    return letter_2
word= input()
replacing(word)
# Out:
# vfgshv
# 'wghtiw'
