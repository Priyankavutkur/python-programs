# %%
def nth_even_number(num):
  if num%2==0:
    return num
  else:
    return num-1

# %%
num = int(input("enter a number to find nth even number: "))
nth_even_number(num)
# Out:
# enter a number to find nth even number: 1256
# 1256
